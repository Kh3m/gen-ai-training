# %% [markdown]
# TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
corpus = [
    "The cat sat on the mat",
    "The dog sat on the log",
    "The cat chased the dog",
]

vectorizer = TfidfVectorizer()

X = vectorizer.fit_transform(corpus)

# %%
vectorizer.get_feature_names_out()
# Out:
# array(['cat', 'chased', 'dog', 'log', 'mat', 'on', 'sat', 'the'],
#       dtype=object)

# %%
X.toarray()
# Out:
# array([[0.37420726, 0.        , 0.        , 0.        , 0.49203758,
#         0.37420726, 0.37420726, 0.58121064],
#        [0.        , 0.        , 0.37420726, 0.49203758, 0.        ,
#         0.37420726, 0.37420726, 0.58121064],
#        [0.40352536, 0.53058735, 0.40352536, 0.        , 0.        ,
#         0.        , 0.        , 0.62674687]])
