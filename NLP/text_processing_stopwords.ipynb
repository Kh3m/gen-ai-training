# %% [markdown]
# ### Stopwords
#
# Stop words are the most common words in any natural language,
# such as 'the', 'is', 'in', 'for', 'where', 'when', 'to', 'at', etc.
# For analyzing text data and building NLP models, these words might
# not add much value to the meaning of the document and are therefore
# typically filtered out. For instance, in a sentence like 'The quick
# brown fox jumps over the lazy dog', words like 'The', 'over', and 'the'
# are stopwords and are often ignored to focus on more meaningful terms.

# %%
paragraph = """
Stop words are the most common words in any natural language, 
such as 'the', 'is', 'in', 'for', 'where', 'when', 'to', 'at', etc. 
For analyzing text data and building NLP models, these words might 
not add much value to the meaning of the document and are therefore 
typically filtered out. For instance, in a sentence like 'The quick 
brown fox jumps over the lazy dog', words like 'The', 'over', and 'the' 
are stopwords and are often ignored to focus on more meaningful terms.
"""

# %%
import nltk

nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\khem6\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize

# %%
sentences = sent_tokenize(paragraph)
print(sentences)
print(len(sentences))
# Out:
# ["\nStop words are the most common words in any natural language, \nsuch as 'the', 'is', 'in', 'for', 'where', 'when', 'to', 'at', etc.", 'For analyzing text data and building NLP models, these words might \nnot add much value to the meaning of the document and are therefore \ntypically filtered out.', "For instance, in a sentence like 'The quick \nbrown fox jumps over the lazy dog', words like 'The', 'over', and 'the' \nare stopwords and are often ignored to focus on more meaningful terms."]
# 3

# %%
print((sentences[0]))
# Out:
# Stop words are the most common words in any natural language,
# such as 'the', 'is', 'in', 'for', 'where', 'when', 'to', 'at', etc.

# %%
stopwords.words("arabic")
# Out:
# ['إذ',
#  'إذا',
#  'إذما',
#  'إذن',
#  'أف',
#  'أقل',
#  'أكثر',
#  'ألا',
#  'إلا',
#  'التي',
#  'الذي',
#  'الذين',
#  'اللاتي',
#  'اللائي',
#  'اللتان',
#  'اللتيا',
#  'اللتين',
#  'اللذان',
#  'اللذين',
#  'اللواتي',
#  'إلى',
#  'إليك',
#  'إليكم',
#  'إليكما',
#  'إليكن',
#  'أم',
#  'أما',
#  'أما',
#  'إما',
#  'أن',
#  'إن',
#  'إنا',
#  'أنا',
#  'أنت',
#  'أنتم',
#  'أنتما',
#  'أنتن',
#  'إنما',
#  'إنه',
#  'أنى',
#  'أنى',
#  'آه',
#  'آها',
#  'أو',
#  'أولاء',
#  'أولئك',
#  'أوه',
#  'آي',
#  'أي',
#  'أيها',
#  'إي',
#  'أين',
#  'أين',
#  'أينما',
#  'إيه',
#  'بخ',
#  'بس',
#  'بعد',
#  'بعض',
#  'بك',
#  'بكم',
#  'بكم',
#  'بكما',
#  'بكن',
#  'بل',
#  'بلى',
#  'بما',
#  'بماذا',
#  'بمن',
#  'بنا',
#  'به',
#  'بها',
#  'بهم',
#  'بهما',
#  'بهن',
#  'بي',
#  'بين',
#  'بيد',
#  'تلك',
#  'تلكم',
#  'تلكما',
#  'ته',
#  'تي',
#  'تين',
#  'تينك',
#  'ثم',
#  'ثمة',
#  'حاشا',
#  'حبذا',
#  'حتى',
#  'حيث',
#  'حيثما',
#  'حين',
#  'خلا',
#  'دون',
# ...

# %%
stopwords.words("english")
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %% [markdown]
# ### Steps in text processing

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# Get the words in the corpus/paragraph
tokenized_words = word_tokenize(paragraph.lower())

# Filter the words to remove the stopwords
words_no_stopwords = [ w for w in tokenized_words if w.lower() not in stopwords.words("english") ]
print(words_no_stopwords)
# Out:
# ['stop', 'words', 'common', 'words', 'natural', 'language', ',', "'the", "'", ',', "'is", "'", ',', "'in", "'", ',', "'for", "'", ',', "'where", "'", ',', "'when", "'", ',', "'to", "'", ',', "'at", "'", ',', 'etc', '.', 'analyzing', 'text', 'data', 'building', 'nlp', 'models', ',', 'words', 'might', 'add', 'much', 'value', 'meaning', 'document', 'therefore', 'typically', 'filtered', '.', 'instance', ',', 'sentence', 'like', "'the", 'quick', 'brown', 'fox', 'jumps', 'lazy', 'dog', "'", ',', 'words', 'like', "'the", "'", ',', "'over", "'", ',', "'the", "'", 'stopwords', 'often', 'ignored', 'focus', 'meaningful', 'terms', '.']

# %%
[ w for w in tokenized_words if w.lower() not in set(stopwords.words("english")) ]
# Out:
# ['stop',
#  'words',
#  'common',
#  'words',
#  'natural',
#  'language',
#  ',',
#  "'the",
#  "'",
#  ',',
#  "'is",
#  "'",
#  ',',
#  "'in",
#  "'",
#  ',',
#  "'for",
#  "'",
#  ',',
#  "'where",
#  "'",
#  ',',
#  "'when",
#  "'",
#  ',',
#  "'to",
#  "'",
#  ',',
#  "'at",
#  "'",
#  ',',
#  'etc',
#  '.',
#  'analyzing',
#  'text',
#  'data',
#  'building',
#  'nlp',
#  'models',
#  ',',
#  'words',
#  'might',
#  'add',
#  'much',
#  'value',
#  'meaning',
#  'document',
#  'therefore',
#  'typically',
#  'filtered',
#  '.',
#  'instance',
#  ',',
#  'sentence',
#  'like',
#  "'the",
#  'quick',
#  'brown',
#  'fox',
#  'jumps',
#  'lazy',
#  'dog',
#  "'",
#  ',',
#  'words',
#  'like',
#  "'the",
#  "'",
#  ',',
#  "'over",
#  "'",
#  ',',
#  "'the",
#  "'",
#  'stopwords',
#  'often',
#  'ignored',
#  'focus',
#  'meaningful',
#  'terms',
#  '.']

# %% [markdown]
# ### Applying Stemming and Lemmatization

# %%
corpus = """
The mysterious old man sat quietly by the shimmering lake, watching as the sun began 
its slow descent behind the distant, jagged mountains. He had spent many years in this 
very spot, thinking about the stories he had heard when he was just a young boy. 
A gentle breeze whispered through the tall pine trees, carrying with it the scent of 
fresh rain and wild lavender. In that moment, everything felt perfectly still, as if 
the world itself was holding its breath.
"""

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# Convert to words
words = word_tokenize(corpus.lower())

# Initialize stopwords
stopwords = stopwords.words("english")

# %% [markdown]
# #### For stemming we use PorterStemmer
#
# It's a bit acurate

# %%
from nltk.stem import PorterStemmer

# Create porter stemmer
porter_stemmer = PorterStemmer()

[{w: porter_stemmer.stem(w)} for w in words if w not in stopwords]
# Out:
# [{'mysterious': 'mysteri'},
#  {'old': 'old'},
#  {'man': 'man'},
#  {'sat': 'sat'},
#  {'quietly': 'quietli'},
#  {'shimmering': 'shimmer'},
#  {'lake': 'lake'},
#  {',': ','},
#  {'watching': 'watch'},
#  {'sun': 'sun'},
#  {'began': 'began'},
#  {'slow': 'slow'},
#  {'descent': 'descent'},
#  {'behind': 'behind'},
#  {'distant': 'distant'},
#  {',': ','},
#  {'jagged': 'jag'},
#  {'mountains': 'mountain'},
#  {'.': '.'},
#  {'spent': 'spent'},
#  {'many': 'mani'},
#  {'years': 'year'},
#  {'spot': 'spot'},
#  {',': ','},
#  {'thinking': 'think'},
#  {'stories': 'stori'},
#  {'heard': 'heard'},
#  {'young': 'young'},
#  {'boy': 'boy'},
#  {'.': '.'},
#  {'gentle': 'gentl'},
#  {'breeze': 'breez'},
#  {'whispered': 'whisper'},
#  {'tall': 'tall'},
#  {'pine': 'pine'},
#  {'trees': 'tree'},
#  {',': ','},
#  {'carrying': 'carri'},
#  {'scent': 'scent'},
#  {'fresh': 'fresh'},
#  {'rain': 'rain'},
#  {'wild': 'wild'},
#  {'lavender': 'lavend'},
#  {'.': '.'},
#  {'moment': 'moment'},
# ...

# %% [markdown]
# #### For lemmatization we use WordNetLemmatizer

# %%
from nltk.stem import WordNetLemmatizer

word_net_lemmatizer = WordNetLemmatizer()

[{w: word_net_lemmatizer.lemmatize(w, pos="v")} for w in words if w not in stopwords]
# Out:
# [{'mysterious': 'mysterious'},
#  {'old': 'old'},
#  {'man': 'man'},
#  {'sat': 'sit'},
#  {'quietly': 'quietly'},
#  {'shimmering': 'shimmer'},
#  {'lake': 'lake'},
#  {',': ','},
#  {'watching': 'watch'},
#  {'sun': 'sun'},
#  {'began': 'begin'},
#  {'slow': 'slow'},
#  {'descent': 'descent'},
#  {'behind': 'behind'},
#  {'distant': 'distant'},
#  {',': ','},
#  {'jagged': 'jag'},
#  {'mountains': 'mountains'},
#  {'.': '.'},
#  {'spent': 'spend'},
#  {'many': 'many'},
#  {'years': 'years'},
#  {'spot': 'spot'},
#  {',': ','},
#  {'thinking': 'think'},
#  {'stories': 'stories'},
#  {'heard': 'hear'},
#  {'young': 'young'},
#  {'boy': 'boy'},
#  {'.': '.'},
#  {'gentle': 'gentle'},
#  {'breeze': 'breeze'},
#  {'whispered': 'whisper'},
#  {'tall': 'tall'},
#  {'pine': 'pine'},
#  {'trees': 'tree'},
#  {',': ','},
#  {'carrying': 'carry'},
#  {'scent': 'scent'},
#  {'fresh': 'fresh'},
#  {'rain': 'rain'},
#  {'wild': 'wild'},
#  {'lavender': 'lavender'},
#  {'.': '.'},
# ...
