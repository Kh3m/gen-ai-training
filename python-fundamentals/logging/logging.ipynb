# %% [markdown]
# ### Logging

# %%
import logging

# %%
logging.basicConfig(
    type=logging.DEBUG,
)

# %%
logging.error("Love")
# Out:
# ERROR:root:Love

# %%
logging.warning("Love")
# Out:
# WARNING:root:Love
