# %% [markdown]
# ### Threading

# %%
import threading
import time

# %%
def print_love():
    time.sleep(10)
    print("I love you so much!")

t1 = threading.Thread(target=print_love)

# %%
t1.start()

# %%
# t1.join()

# %%
print("We got here cause no join")
# Out:
# We got here cause no join
# I love you so much!
