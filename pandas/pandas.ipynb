# %%
import pandas as pd

dic = {
    "Name": ["Abdulkareem", "Khem", "Adams"],
    "Age": [23, 18, 26],
    "Gender": ["Male", "Female", "Male"],
}

df = pd.DataFrame(dic)

df
# Out:
#           Name  Age  Gender
# 0  Abdulkareem   23    Male
# 1         Khem   18  Female
# 2        Adams   26    Male

# %%
print(df.iloc[0])
print("==================")
print(df.iloc[0]["Name"])
# Out:
# Name      Abdulkareem
# Age                23
# Gender           Male
# Name: 0, dtype: object
# ...
# Abdulkareem

# %%
type(df.iloc[0])
# Out:
# pandas.core.series.Series

# %%
df["Age"]
# Out:
# 0    23
# 1    18
# 2    26
# Name: Age, dtype: int64

# %%
type(df["Age"])
# Out:
# pandas.core.series.Series

# %%
print(df)
print(df.describe())
# Out:
#           Name  Age  Gender
# 0  Abdulkareem   23    Male
# 1         Khem   18  Female
# 2        Adams   26    Male
#              Age
# count   3.000000
# mean   22.333333
# std     4.041452
# min    18.000000
# 25%    20.500000
# 50%    23.000000
# 75%    24.500000
# max    26.000000

# %%
dic = {
    "Name": ["Abdulkareem", "Khem", "Adams"],
    "Age": [23, 18, 26],
    "Gender": ["Male", "Female", "Male"],
    "Weight": [34,12.67,9.3]
}

df = pd.DataFrame(dic)

print(df)
df.describe()
# Out:
#           Name  Age  Gender  Weight
# 0  Abdulkareem   23    Male   34.00
# 1         Khem   18  Female   12.67
# 2        Adams   26    Male    9.30
#              Age     Weight
# count   3.000000   3.000000
# mean   22.333333  18.656667
# std     4.041452  13.394127
# min    18.000000   9.300000
# 25%    20.500000  10.985000
# 50%    23.000000  12.670000
# 75%    24.500000  23.335000
# max    26.000000  34.000000

# %%
df
# Out:
#           Name  Age  Gender  Weight
# 0  Abdulkareem   23    Male   34.00
# 1         Khem   18  Female   12.67
# 2        Adams   26    Male    9.30

# %%
#  df["Age"] == 23
df[ [ True, False, True ] ]
# Out:
#           Name  Age Gender  Weight
# 0  Abdulkareem   23   Male    34.0
# 2        Adams   26   Male     9.3

# %%
df[ df["Age"] >= 23 ]
# Out:
#           Name  Age Gender  Weight
# 0  Abdulkareem   23   Male    34.0
# 2        Adams   26   Male     9.3

# %%
print(df.head(1)) # By default gives the first five (5) rows
print("===========")
print(df.tail(1)) # By default gives the last five (5) rows
print("===========")
print(df.info(1))
print("===========")
print(df.index)
print("===========")
print(df.columns)
# Out:
#           Name  Age Gender  Weight
# 0  Abdulkareem   23   Male    34.0
# ...
#     Name  Age Gender  Weight
# 2  Adams   26   Male     9.3
# ...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     3 non-null      int64
#  2   Gender  3 non-null      object
#  3   Weight  3 non-null      float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 228.0+ bytes
# None
# ...
# RangeIndex(start=0, stop=3, step=1)
# ...
# Index(['Name', 'Age', 'Gender', 'Weight'], dtype='object')

# %%
df
# Out:
#           Name  Age  Gender  Weight
# 0  Abdulkareem   23    Male   34.00
# 1         Khem   18  Female   12.67
# 2        Adams   26    Male    9.30

# %%
df.loc[ (df["Age"] == 18) | (df["Name"].str.endswith("m")) ]
# Out:
#           Name  Age Gender  Weight
# 0  Abdulkareem   23   Male   34.00
# 1         Khem   18   Male   12.67

# %%
df.loc[ (df["Age"] == 18) | (df["Name"].str.endswith("m")), "Gender" ] = "M"

# %%
df
# Out:
#           Name  Age Gender  Weight
# 0  Abdulkareem   23      M   34.00
# 1         Khem   18      M   12.67
# 2        Adams   26   Male    9.30

# %%
print(df["Age"].mean())
print(df["Age"].sum())
print(df["Age"].count())
# Out:
# 22.333333333333332
# 67
# 3
